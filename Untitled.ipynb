# %%
import pandas as pd
df = df = pd.read_csv('Users/soualmouajel/Desktop/Ironhack/lab-sessions/week-3/day-1/sql-project/top50.csv.csv')

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import pandas as pd
# ----> 2 df = df = pd.read_csv('Users/soualmouajel/Desktop/Ironhack/lab-sessions/week-3/day-1/sql-project/top50.csv.csv')
#       4 df
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /Users/souadmouajel/Desktop/Ironhack/lab-sessions/week-2/day-2/lab-dw-data-cleaning-and-formatting

# %%
# Full file path
file_path = '/Users/souadmouajel/Desktop/Ironhack/lab-sessions/week-3/sql_project/top50.csv'

# Read CSV
df = pd.read_csv(file_path, encoding='latin1')

# %%
df.head(20)
# Out:
#     Unnamed: 0                                     Track.Name    Artist.Name  \
# 0            1                                       Señorita   Shawn Mendes
# 1            2                                          China       Anuel AA
# 2            3                  boyfriend (with Social House)  Ariana Grande
# 3            4                Beautiful People (feat. Khalid)     Ed Sheeran
# 4            5                    Goodbyes (Feat. Young Thug)    Post Malone
# 5            6              I Don't Care (with Justin Bieber)     Ed Sheeran
# 6            7                                         Ransom      Lil Tecca
# 7            8                              How Do You Sleep?      Sam Smith
# 8            9                          Old Town Road - Remix      Lil Nas X
# 9           10                                        bad guy  Billie Eilish
# 10          11                                       Callaita      Bad Bunny
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
df["Popularity"].head(10)
# Out:
# 0    79
# 1    92
# 2    85
# 3    86
# 4    94
# 5    84
# 6    92
# 7    90
# 8    87
# 9    95
# Name: Popularity, dtype: int64

# %%
import pandas as pd
NY_Dataset = '/Users/souadmouajel/Desktop/Ironhack/lab-sessions/week-3/sql_project/AB_NYC_2019.csv'

# Read CSV
df_NY = pd.read_csv(file_path, encoding='latin1')

# %%
df_NY.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB
